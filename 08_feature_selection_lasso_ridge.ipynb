# %%
"""
Feature Selection using Lasso and Ridge Regression
===================================================

Purpose: Identify the most predictive features from the full ML feature set
         (59 for P1A, 61 for P3A) using L1 (Lasso) and L2 (Ridge) regularization.

Strategy:
1. Train Lasso and Ridge models with cross-validation to find optimal alpha
2. Identify features with non-zero coefficients (Lasso) or high importance (Ridge)
3. Select top N features based on coefficient magnitude
4. Train XGBoost on selected features
5. Compare performance: Full features vs Selected features vs CORE features

Author: Data Science Pipeline
Date: 2025-10-17
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
import warnings
import json
import os

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# ==============================================================================
# CONFIGURATION
# ==============================================================================

DATA_DIR = 'data/processed/'
OUTPUT_DIR = 'data/models/feature_selection/'
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(f'{OUTPUT_DIR}plots/', exist_ok=True)

HORIZONS = [1, 5, 10, 20]
TOP_N_FEATURES = [10, 15, 20, 25]  # Try different feature set sizes
RANDOM_STATE = 73

print('='*80)
print('FEATURE SELECTION: LASSO & RIDGE REGULARIZATION')
print('='*80)
print('Strategy: Identify most predictive features from full ML feature set')
print(f'Top N features to test: {TOP_N_FEATURES}')
print(f'Target horizons: {HORIZONS} business days')
print('='*80)

# ==============================================================================
# LOAD DATA
# ==============================================================================

print('\nLoading ML feature datasets...')
print('-'*80)

# Load P1A ML features (59 features)
p1a_train = pd.read_csv(f'{DATA_DIR}p1a_ml_train.csv')
p1a_val = pd.read_csv(f'{DATA_DIR}p1a_ml_val.csv')
p1a_test = pd.read_csv(f'{DATA_DIR}p1a_ml_test.csv')
print(f'[LOADED] P1A ML: Train={p1a_train.shape}, Val={p1a_val.shape}, Test={p1a_test.shape}')

# Load P3A ML features (61 features)
p3a_train = pd.read_csv(f'{DATA_DIR}p3a_ml_train.csv')
p3a_val = pd.read_csv(f'{DATA_DIR}p3a_ml_val.csv')
p3a_test = pd.read_csv(f'{DATA_DIR}p3a_ml_test.csv')
print(f'[LOADED] P3A ML: Train={p3a_train.shape}, Val={p3a_val.shape}, Test={p3a_test.shape}')

# Load targets
targets_train = pd.read_csv(f'{DATA_DIR}targets_train.csv')
targets_val = pd.read_csv(f'{DATA_DIR}targets_val.csv')
targets_test = pd.read_csv(f'{DATA_DIR}targets_test.csv')
print(f'[LOADED] Targets: Train={targets_train.shape}, Val={targets_val.shape}, Test={targets_test.shape}')

# Feature columns
p1a_features = [c for c in p1a_train.columns if c != 'Date']
p3a_features = [c for c in p3a_train.columns if c != 'Date']

print(f'\nFeature counts:')
print(f'  P1A (Atlantic): {len(p1a_features)} features')
print(f'  P3A (Pacific):  {len(p3a_features)} features')
print('='*80)

# ==============================================================================
# FEATURE SELECTION FUNCTIONS
# ==============================================================================

def select_features_lasso(X_train, y_train, feature_names, route_name, horizon, top_n=20):
    """
    Select top N features using Lasso (L1 regularization).

    Lasso drives weak coefficients to exactly zero, providing automatic feature selection.
    """
    print(f'\n{route_name} - h={horizon} - Lasso Feature Selection (top {top_n})')
    print('-'*60)

    # Remove NaN values in targets
    train_mask = ~y_train.isna()
    X_clean = X_train[train_mask].copy()
    y_clean = y_train[train_mask].copy()

    # Handle NaN values in features (forward fill, then drop any remaining NaNs)
    print(f'  Handling missing values in features...')
    X_clean = X_clean.fillna(method='ffill').fillna(method='bfill')

    # If any columns still have NaNs, drop those columns
    cols_with_nan = X_clean.columns[X_clean.isna().any()].tolist()
    if cols_with_nan:
        print(f'  Dropping {len(cols_with_nan)} features with remaining NaNs')
        X_clean = X_clean.drop(columns=cols_with_nan)
        feature_names = [f for f in feature_names if f not in cols_with_nan]

    # Additional scaling (data already scaled, but Lasso benefits from re-normalization)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_clean)

    # Lasso with cross-validation to find optimal alpha
    print('  Running LassoCV (finding optimal alpha)...')
    lasso = LassoCV(cv=5, random_state=RANDOM_STATE, max_iter=5000, n_jobs=-1)
    lasso.fit(X_scaled, y_clean)

    print(f'  Optimal alpha: {lasso.alpha_:.6f}')
    print(f'  Non-zero coefficients: {np.sum(lasso.coef_ != 0)} / {len(feature_names)}')

    # Get feature importance (absolute coefficient values)
    feature_importance = pd.DataFrame({
        'feature': feature_names,
        'coefficient': lasso.coef_,
        'abs_coefficient': np.abs(lasso.coef_)
    }).sort_values('abs_coefficient', ascending=False)

    # Select top N
    selected_features = feature_importance.head(top_n)['feature'].tolist()

    print(f'  Top {top_n} features selected:')
    for i, feat in enumerate(selected_features[:10], 1):  # Show first 10
        coef = feature_importance[feature_importance['feature'] == feat]['coefficient'].values[0]
        print(f'    {i:2d}. {feat[:50]:50s}  (coef: {coef:+.4f})')
    if top_n > 10:
        print(f'    ... and {top_n - 10} more')

    return selected_features, feature_importance


def select_features_ridge(X_train, y_train, feature_names, route_name, horizon, top_n=20):
    """
    Select top N features using Ridge (L2 regularization).

    Ridge shrinks coefficients but doesn't eliminate them. We select features
    with the largest absolute coefficients.
    """
    print(f'\n{route_name} - h={horizon} - Ridge Feature Selection (top {top_n})')
    print('-'*60)

    # Remove NaN values in targets
    train_mask = ~y_train.isna()
    X_clean = X_train[train_mask].copy()
    y_clean = y_train[train_mask].copy()

    # Handle NaN values in features (forward fill, then drop any remaining NaNs)
    print(f'  Handling missing values in features...')
    X_clean = X_clean.fillna(method='ffill').fillna(method='bfill')

    # If any columns still have NaNs, drop those columns
    cols_with_nan = X_clean.columns[X_clean.isna().any()].tolist()
    if cols_with_nan:
        print(f'  Dropping {len(cols_with_nan)} features with remaining NaNs')
        X_clean = X_clean.drop(columns=cols_with_nan)
        feature_names = [f for f in feature_names if f not in cols_with_nan]

    # Scaling
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_clean)

    # Ridge with cross-validation
    print('  Running RidgeCV (finding optimal alpha)...')
    ridge = RidgeCV(cv=5, alphas=np.logspace(-3, 3, 100))
    ridge.fit(X_scaled, y_clean)

    print(f'  Optimal alpha: {ridge.alpha_:.6f}')

    # Get feature importance
    feature_importance = pd.DataFrame({
        'feature': feature_names,
        'coefficient': ridge.coef_,
        'abs_coefficient': np.abs(ridge.coef_)
    }).sort_values('abs_coefficient', ascending=False)

    # Select top N
    selected_features = feature_importance.head(top_n)['feature'].tolist()

    print(f'  Top {top_n} features selected:')
    for i, feat in enumerate(selected_features[:10], 1):
        coef = feature_importance[feature_importance['feature'] == feat]['coefficient'].values[0]
        print(f'    {i:2d}. {feat[:50]:50s}  (coef: {coef:+.4f})')
    if top_n > 10:
        print(f'    ... and {top_n - 10} more')

    return selected_features, feature_importance


def plot_feature_importance(importance_df, route_name, horizon, method, top_n=20):
    """
    Plot feature importance from Lasso or Ridge.
    """
    top_features = importance_df.head(top_n)

    fig, ax = plt.subplots(figsize=(10, 8))
    colors = ['darkred' if c < 0 else 'darkblue' for c in top_features['coefficient']]
    ax.barh(range(len(top_features)), top_features['abs_coefficient'], color=colors, alpha=0.7)
    ax.set_yticks(range(len(top_features)))
    ax.set_yticklabels(top_features['feature'], fontsize=8)
    ax.invert_yaxis()
    ax.set_xlabel('Absolute Coefficient', fontsize=11)
    ax.set_title(f'{route_name} - h={horizon} - {method} Feature Importance (Top {top_n})',
                 fontsize=12, fontweight='bold')
    ax.grid(True, alpha=0.3, axis='x')

    plt.tight_layout()
    plt.savefig(f'{OUTPUT_DIR}plots/{route_name}_h{horizon}_{method}_importance.png', dpi=150)
    plt.close()

# ==============================================================================
# FEATURE SELECTION FOR ALL ROUTES AND HORIZONS
# ==============================================================================

feature_selections = {}

print('\n' + '='*80)
print('PHASE 1: FEATURE SELECTION (Lasso & Ridge)')
print('='*80)

for route_name, X_train, feature_names in [
    ('P1A_82', p1a_train, p1a_features),
    ('P3A_82', p3a_train, p3a_features)
]:
    print(f'\n--- {route_name} ---')

    for h in HORIZONS:
        target_col = f'{route_name}_h{h}'
        y_train = targets_train[target_col]

        # Try multiple feature set sizes
        for top_n in TOP_N_FEATURES:
            # Lasso
            lasso_features, lasso_importance = select_features_lasso(
                X_train[feature_names], y_train, feature_names, route_name, h, top_n
            )
            feature_selections[f'{route_name}_h{h}_lasso_{top_n}'] = {
                'route': route_name,
                'horizon': h,
                'method': 'lasso',
                'top_n': top_n,
                'features': lasso_features,
                'importance': lasso_importance
            }

            # Ridge
            ridge_features, ridge_importance = select_features_ridge(
                X_train[feature_names], y_train, feature_names, route_name, h, top_n
            )
            feature_selections[f'{route_name}_h{h}_ridge_{top_n}'] = {
                'route': route_name,
                'horizon': h,
                'method': 'ridge',
                'top_n': top_n,
                'features': ridge_features,
                'importance': ridge_importance
            }

        # Plot for h=1 with top 20 features
        if h == 1:
            lasso_key = f'{route_name}_h{h}_lasso_20'
            ridge_key = f'{route_name}_h{h}_ridge_20'
            plot_feature_importance(
                feature_selections[lasso_key]['importance'],
                route_name, h, 'Lasso', 20
            )
            plot_feature_importance(
                feature_selections[ridge_key]['importance'],
                route_name, h, 'Ridge', 20
            )

print('\n' + '='*80)
print('Feature selection complete! Testing XGBoost with selected features...')
print('='*80)

# ==============================================================================
# TRAIN XGBOOST ON SELECTED FEATURES
# ==============================================================================

def train_xgboost_selected(X_train, y_train, X_val, y_val, selected_features,
                           route_name, horizon, method, top_n):
    """
    Train XGBoost on selected features.
    """
    # Remove NaN values in targets
    train_mask = ~y_train.isna()
    val_mask = ~y_val.isna()

    # Select only the features that exist (some may have been dropped during feature selection)
    available_features = [f for f in selected_features if f in X_train.columns]

    X_train_clean = X_train[available_features][train_mask].reset_index(drop=True)
    y_train_clean = y_train[train_mask].reset_index(drop=True)
    X_val_clean = X_val[available_features][val_mask].reset_index(drop=True)
    y_val_clean = y_val[val_mask].reset_index(drop=True)

    # XGBoost can handle NaN natively, but let's fill them for consistency
    X_train_clean = X_train_clean.fillna(method='ffill').fillna(method='bfill').fillna(0)
    X_val_clean = X_val_clean.fillna(method='ffill').fillna(method='bfill').fillna(0)

    # Simple XGBoost with default params (fast training)
    model = xgb.XGBRegressor(
        max_depth=5,
        learning_rate=0.1,
        n_estimators=500,
        min_child_weight=3,
        gamma=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=0.5,
        reg_lambda=1.0,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=RANDOM_STATE,
        n_jobs=-1
    )

    model.fit(X_train_clean, y_train_clean, verbose=False)

    # Evaluate
    y_val_pred = model.predict(X_val_clean)
    val_rmse = np.sqrt(mean_squared_error(y_val_clean, y_val_pred))
    val_mae = mean_absolute_error(y_val_clean, y_val_pred)
    val_r2 = r2_score(y_val_clean, y_val_pred)

    return model, {'rmse': val_rmse, 'mae': val_mae, 'r2': val_r2}


print('\n' + '='*80)
print('PHASE 2: XGBOOST TRAINING ON SELECTED FEATURES')
print('='*80)

xgb_results = []

for route_name, X_train, X_val, feature_names in [
    ('P1A_82', p1a_train, p1a_val, p1a_features),
    ('P3A_82', p3a_train, p3a_val, p3a_features)
]:
    print(f'\n--- {route_name} ---')

    for h in HORIZONS:
        target_col = f'{route_name}_h{h}'
        y_train = targets_train[target_col]
        y_val = targets_val[target_col]

        print(f'\nHorizon {h}:')

        for top_n in TOP_N_FEATURES:
            for method in ['lasso', 'ridge']:
                key = f'{route_name}_h{h}_{method}_{top_n}'
                selected_features = feature_selections[key]['features']

                print(f'  Training XGBoost with {method.upper()} {top_n} features...', end=' ')

                model, metrics = train_xgboost_selected(
                    X_train, y_train, X_val, y_val, selected_features,
                    route_name, h, method, top_n
                )

                print(f'RMSE=${metrics["rmse"]:,.2f}, R²={metrics["r2"]:.4f}')

                xgb_results.append({
                    'route': route_name,
                    'horizon': h,
                    'method': method,
                    'top_n': top_n,
                    'val_rmse': metrics['rmse'],
                    'val_mae': metrics['mae'],
                    'val_r2': metrics['r2'],
                    'selected_features': selected_features
                })

print('\n' + '='*80)
print('XGBoost training complete!')
print('='*80)

# ==============================================================================
# RESULTS ANALYSIS
# ==============================================================================

xgb_results_df = pd.DataFrame(xgb_results)

print('\n' + '='*80)
print('RESULTS SUMMARY: FEATURE SELECTION IMPACT')
print('='*80)

# Find best configuration for each route
for route in ['P1A_82', 'P3A_82']:
    print(f'\n{route}:')
    print('-'*80)

    route_results = xgb_results_df[
        (xgb_results_df['route'] == route) &
        (xgb_results_df['horizon'] == 1)  # Focus on h=1
    ].sort_values('val_rmse')

    print('Top 5 configurations (by RMSE):')
    for i, (_, row) in enumerate(route_results.head(5).iterrows(), 1):
        print(f"  {i}. {row['method'].upper()} {row['top_n']:2d} features: "
              f"RMSE=${row['val_rmse']:>8,.2f}  |  R²={row['val_r2']:>7.4f}")

    # Best configuration
    best = route_results.iloc[0]
    print(f"\n✓ BEST: {best['method'].upper()} with {best['top_n']} features")
    print(f"  RMSE: ${best['val_rmse']:,.2f}")
    print(f"  R²:   {best['val_r2']:.4f}")

# ==============================================================================
# COMPARISON WITH BASELINES
# ==============================================================================

print('\n' + '='*80)
print('BASELINE COMPARISON (h=1)')
print('='*80)

baselines = pd.DataFrame([
    {'route': 'P1A_82', 'model': 'SARIMAX', 'features': 12, 'rmse': 7573.66, 'r2': None},
    {'route': 'P1A_82', 'model': 'XGBoost CORE', 'features': 12, 'rmse': None, 'r2': None},  # Fill from Script 07
    {'route': 'P1A_82', 'model': 'XGBoost FULL', 'features': 59, 'rmse': 4284.31, 'r2': -2.79},
    {'route': 'P3A_82', 'model': 'SARIMAX', 'features': 12, 'rmse': 2477.18, 'r2': None},
    {'route': 'P3A_82', 'model': 'XGBoost CORE', 'features': 12, 'rmse': None, 'r2': None},
    {'route': 'P3A_82', 'model': 'XGBoost FULL', 'features': 61, 'rmse': 1098.56, 'r2': 0.81},
])

# Add best selected feature results
for route in ['P1A_82', 'P3A_82']:
    best_result = xgb_results_df[
        (xgb_results_df['route'] == route) &
        (xgb_results_df['horizon'] == 1)
    ].sort_values('val_rmse').iloc[0]

    baselines = pd.concat([baselines, pd.DataFrame([{
        'route': route,
        'model': f"XGBoost {best_result['method'].upper()}",
        'features': best_result['top_n'],
        'rmse': best_result['val_rmse'],
        'r2': best_result['val_r2']
    }])], ignore_index=True)

# Display
for route in ['P1A_82', 'P3A_82']:
    print(f'\n{route}:')
    route_baselines = baselines[baselines['route'] == route].sort_values('rmse')
    for _, row in route_baselines.iterrows():
        r2_str = f"{row['r2']:>7.4f}" if pd.notna(row['r2']) else "    N/A"
        print(f"  {row['model']:25s} ({row['features']:2.0f} feat): "
              f"RMSE ${row['rmse']:>10,.2f}  |  R² {r2_str}")

# ==============================================================================
# SAVE RESULTS
# ==============================================================================

print('\n' + '='*80)
print('SAVING RESULTS')
print('='*80)

# Save XGBoost results
xgb_results_df.to_csv(f'{OUTPUT_DIR}xgboost_feature_selection_results.csv', index=False)
print(f'[SAVED] xgboost_feature_selection_results.csv')

# Save feature importance tables
for key, selection in feature_selections.items():
    if selection['horizon'] == 1:  # Save only h=1 for brevity
        filename = f"{OUTPUT_DIR}{selection['route']}_h{selection['horizon']}_{selection['method']}_{selection['top_n']}_importance.csv"
        selection['importance'].to_csv(filename, index=False)
print(f'[SAVED] Feature importance CSVs ({len([k for k in feature_selections.keys() if "_h1_" in k])} files)')

# Save baseline comparison
baselines.to_csv(f'{OUTPUT_DIR}baseline_comparison_all_methods.csv', index=False)
print(f'[SAVED] baseline_comparison_all_methods.csv')

# Save metadata
metadata = {
    'strategy': 'Feature selection using Lasso and Ridge regularization',
    'methods': ['lasso', 'ridge'],
    'top_n_tested': TOP_N_FEATURES,
    'routes': ['P1A_82', 'P3A_82'],
    'horizons': HORIZONS,
    'original_features': {'P1A': len(p1a_features), 'P3A': len(p3a_features)},
    'random_state': RANDOM_STATE
}

with open(f'{OUTPUT_DIR}metadata.json', 'w') as f:
    json.dump(metadata, f, indent=2)
print(f'[SAVED] metadata.json')

print('\n' + '='*80)
print('SCRIPT COMPLETE!')
print('='*80)
print(f'\nOutputs saved to: {OUTPUT_DIR}')
print('\nKey files:')
print('  - xgboost_feature_selection_results.csv: All configurations tested')
print('  - baseline_comparison_all_methods.csv: Comparison with SARIMAX and full XGBoost')
print('  - plots/: Feature importance visualizations')
print('\nNext steps:')
print('  1. Review baseline_comparison_all_methods.csv')
print('  2. Check if P1A R² improved (should be positive)')
print('  3. Identify optimal feature count (sweet spot between 10-25)')
print('  4. Use best configuration for final production model')
print('='*80)
# Out:
# ================================================================================
# FEATURE SELECTION: LASSO & RIDGE REGULARIZATION
# ================================================================================
# Strategy: Identify most predictive features from full ML feature set
# Top N features to test: [10, 15, 20, 25]
# Target horizons: [1, 5, 10, 20] business days
# ================================================================================
#
# Loading ML feature datasets...
# --------------------------------------------------------------------------------
# [LOADED] P1A ML: Train=(705, 60), Val=(125, 60), Test=(326, 60)
# [LOADED] P3A ML: Train=(705, 62), Val=(125, 62), Test=(326, 62)
# [LOADED] Targets: Train=(705, 11), Val=(125, 11), Test=(326, 11)
#
# Feature counts:
#   P1A (Atlantic): 59 features
#   P3A (Pacific):  61 features
# ================================================================================
#
# ================================================================================
# PHASE 1: FEATURE SELECTION (Lasso & Ridge)
# ================================================================================
#
# --- P1A_82 ---
#
# P1A_82 - h=1 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 189.635974
#   Non-zero coefficients: 14 / 59
#   Top 10 features selected:
#      1. P1EA_Contango                                       (coef: -4168.3464)
#      2. P1EA_Basis                                          (coef: -2884.4962)
#      3. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1254.3846)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1196.3242)
#      5. PDITC                                               (coef: +1193.7653)
#      6. Germany BFI Production                              (coef: -893.9623)
#      7. P8-TCE                                              (coef: +721.9523)
#      8. Industrial Production  USA                          (coef: +620.8914)
#      9. Germany Steel Production                            (coef: +559.6051)
#     10. Capesize Fleet Growth                               (coef: +510.3256)
#
# P1A_82 - h=1 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 46.415888
#   Top 10 features selected:
#      1. P1EA_Basis                                          (coef: -2541.8569)
#      2. P1EA_Contango                                       (coef: -2104.3451)
#      3. P1EA_Slope                                          (coef: -1522.0048)
#      4. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1374.7752)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1068.1857)
#      6. PDITC                                               (coef: +1042.5860)
#      7. P8-TCE                                              (coef: +1025.8013)
#      8. Panamax Orderbook % Fleet                           (coef: +955.8262)
#      9. Germany Steel Production                            (coef: +923.9283)
#     10. C8                                                  (coef: +890.1983)
#
# P1A_82 - h=1 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 189.635974
#   Non-zero coefficients: 14 / 59
#   Top 15 features selected:
#      1. P1EA_Contango                                       (coef: -4168.3464)
#      2. P1EA_Basis                                          (coef: -2884.4962)
#      3. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1254.3846)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1196.3242)
#      5. PDITC                                               (coef: +1193.7653)
#      6. Germany BFI Production                              (coef: -893.9623)
#      7. P8-TCE                                              (coef: +721.9523)
#      8. Industrial Production  USA                          (coef: +620.8914)
#      9. Germany Steel Production                            (coef: +559.6051)
#     10. Capesize Fleet Growth                               (coef: +510.3256)
#     ... and 5 more
#
# P1A_82 - h=1 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 46.415888
#   Top 15 features selected:
#      1. P1EA_Basis                                          (coef: -2541.8569)
#      2. P1EA_Contango                                       (coef: -2104.3451)
#      3. P1EA_Slope                                          (coef: -1522.0048)
#      4. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1374.7752)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1068.1857)
#      6. PDITC                                               (coef: +1042.5860)
#      7. P8-TCE                                              (coef: +1025.8013)
#      8. Panamax Orderbook % Fleet                           (coef: +955.8262)
#      9. Germany Steel Production                            (coef: +923.9283)
#     10. C8                                                  (coef: +890.1983)
#     ... and 5 more
#
# P1A_82 - h=1 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 189.635974
#   Non-zero coefficients: 14 / 59
#   Top 20 features selected:
#      1. P1EA_Contango                                       (coef: -4168.3464)
#      2. P1EA_Basis                                          (coef: -2884.4962)
#      3. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1254.3846)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1196.3242)
#      5. PDITC                                               (coef: +1193.7653)
#      6. Germany BFI Production                              (coef: -893.9623)
#      7. P8-TCE                                              (coef: +721.9523)
#      8. Industrial Production  USA                          (coef: +620.8914)
#      9. Germany Steel Production                            (coef: +559.6051)
#     10. Capesize Fleet Growth                               (coef: +510.3256)
#     ... and 10 more
#
# P1A_82 - h=1 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 46.415888
#   Top 20 features selected:
#      1. P1EA_Basis                                          (coef: -2541.8569)
#      2. P1EA_Contango                                       (coef: -2104.3451)
#      3. P1EA_Slope                                          (coef: -1522.0048)
#      4. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1374.7752)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1068.1857)
#      6. PDITC                                               (coef: +1042.5860)
#      7. P8-TCE                                              (coef: +1025.8013)
#      8. Panamax Orderbook % Fleet                           (coef: +955.8262)
#      9. Germany Steel Production                            (coef: +923.9283)
#     10. C8                                                  (coef: +890.1983)
#     ... and 10 more
#
# P1A_82 - h=1 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 189.635974
#   Non-zero coefficients: 14 / 59
#   Top 25 features selected:
#      1. P1EA_Contango                                       (coef: -4168.3464)
#      2. P1EA_Basis                                          (coef: -2884.4962)
#      3. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1254.3846)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1196.3242)
#      5. PDITC                                               (coef: +1193.7653)
#      6. Germany BFI Production                              (coef: -893.9623)
#      7. P8-TCE                                              (coef: +721.9523)
#      8. Industrial Production  USA                          (coef: +620.8914)
#      9. Germany Steel Production                            (coef: +559.6051)
#     10. Capesize Fleet Growth                               (coef: +510.3256)
#     ... and 15 more
#
# P1A_82 - h=1 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 46.415888
#   Top 25 features selected:
#      1. P1EA_Basis                                          (coef: -2541.8569)
#      2. P1EA_Contango                                       (coef: -2104.3451)
#      3. P1EA_Slope                                          (coef: -1522.0048)
#      4. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1374.7752)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1068.1857)
#      6. PDITC                                               (coef: +1042.5860)
#      7. P8-TCE                                              (coef: +1025.8013)
#      8. Panamax Orderbook % Fleet                           (coef: +955.8262)
#      9. Germany Steel Production                            (coef: +923.9283)
#     10. C8                                                  (coef: +890.1983)
#     ... and 15 more
#
# P1A_82 - h=5 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 148.736086
#   Non-zero coefficients: 20 / 59
#   Top 10 features selected:
#      1. P1EA_Basis                                          (coef: -3111.5350)
#      2. P1EA_Contango                                       (coef: -2141.2133)
#      3. P1EA_Slope                                          (coef: -1697.9733)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1681.7393)
#      5. Industrial Production  USA                          (coef: +1041.0354)
#      6. Capesize Fleet Growth                               (coef: +996.1339)
#      7. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -726.3021)
#      8. PDRVI                                               (coef: -714.3724)
#      9. Germany Steel Production                            (coef: +655.7761)
#     10. Germany BFI Production                              (coef: -548.1299)
#
# P1A_82 - h=5 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 40.370173
#   Top 10 features selected:
#      1. P1EA_Basis                                          (coef: -2663.3430)
#      2. P1EA_Slope                                          (coef: -1838.2316)
#      3. P1EA_Contango                                       (coef: -1654.4722)
#      4. Panamax Orderbook % Fleet                           (coef: +1391.3597)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1195.4259)
#      6. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1045.5472)
#      7. Germany Steel Production                            (coef: +1035.1219)
#      8. Industrial Production  USA                          (coef: +798.4673)
#      9. C8                                                  (coef: +747.2923)
#     10. LPDSRA                                              (coef: +736.4975)
#
# P1A_82 - h=5 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 148.736086
#   Non-zero coefficients: 20 / 59
#   Top 15 features selected:
#      1. P1EA_Basis                                          (coef: -3111.5350)
#      2. P1EA_Contango                                       (coef: -2141.2133)
#      3. P1EA_Slope                                          (coef: -1697.9733)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1681.7393)
#      5. Industrial Production  USA                          (coef: +1041.0354)
#      6. Capesize Fleet Growth                               (coef: +996.1339)
#      7. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -726.3021)
#      8. PDRVI                                               (coef: -714.3724)
#      9. Germany Steel Production                            (coef: +655.7761)
#     10. Germany BFI Production                              (coef: -548.1299)
#     ... and 5 more
#
# P1A_82 - h=5 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 40.370173
#   Top 15 features selected:
#      1. P1EA_Basis                                          (coef: -2663.3430)
#      2. P1EA_Slope                                          (coef: -1838.2316)
#      3. P1EA_Contango                                       (coef: -1654.4722)
#      4. Panamax Orderbook % Fleet                           (coef: +1391.3597)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1195.4259)
#      6. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1045.5472)
#      7. Germany Steel Production                            (coef: +1035.1219)
#      8. Industrial Production  USA                          (coef: +798.4673)
#      9. C8                                                  (coef: +747.2923)
#     10. LPDSRA                                              (coef: +736.4975)
#     ... and 5 more
#
# P1A_82 - h=5 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 148.736086
#   Non-zero coefficients: 20 / 59
#   Top 20 features selected:
#      1. P1EA_Basis                                          (coef: -3111.5350)
#      2. P1EA_Contango                                       (coef: -2141.2133)
#      3. P1EA_Slope                                          (coef: -1697.9733)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1681.7393)
#      5. Industrial Production  USA                          (coef: +1041.0354)
#      6. Capesize Fleet Growth                               (coef: +996.1339)
#      7. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -726.3021)
#      8. PDRVI                                               (coef: -714.3724)
#      9. Germany Steel Production                            (coef: +655.7761)
#     10. Germany BFI Production                              (coef: -548.1299)
#     ... and 10 more
#
# P1A_82 - h=5 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 40.370173
#   Top 20 features selected:
#      1. P1EA_Basis                                          (coef: -2663.3430)
#      2. P1EA_Slope                                          (coef: -1838.2316)
#      3. P1EA_Contango                                       (coef: -1654.4722)
#      4. Panamax Orderbook % Fleet                           (coef: +1391.3597)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1195.4259)
#      6. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1045.5472)
#      7. Germany Steel Production                            (coef: +1035.1219)
#      8. Industrial Production  USA                          (coef: +798.4673)
#      9. C8                                                  (coef: +747.2923)
#     10. LPDSRA                                              (coef: +736.4975)
#     ... and 10 more
#
# P1A_82 - h=5 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 148.736086
#   Non-zero coefficients: 20 / 59
#   Top 25 features selected:
#      1. P1EA_Basis                                          (coef: -3111.5350)
#      2. P1EA_Contango                                       (coef: -2141.2133)
#      3. P1EA_Slope                                          (coef: -1697.9733)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1681.7393)
#      5. Industrial Production  USA                          (coef: +1041.0354)
#      6. Capesize Fleet Growth                               (coef: +996.1339)
#      7. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -726.3021)
#      8. PDRVI                                               (coef: -714.3724)
#      9. Germany Steel Production                            (coef: +655.7761)
#     10. Germany BFI Production                              (coef: -548.1299)
#     ... and 15 more
#
# P1A_82 - h=5 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 40.370173
#   Top 25 features selected:
#      1. P1EA_Basis                                          (coef: -2663.3430)
#      2. P1EA_Slope                                          (coef: -1838.2316)
#      3. P1EA_Contango                                       (coef: -1654.4722)
#      4. Panamax Orderbook % Fleet                           (coef: +1391.3597)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +1195.4259)
#      6. Panamax Bulkcarrier 65-100,000 dwt Atlantic Deploy  (coef: -1045.5472)
#      7. Germany Steel Production                            (coef: +1035.1219)
#      8. Industrial Production  USA                          (coef: +798.4673)
#      9. C8                                                  (coef: +747.2923)
#     10. LPDSRA                                              (coef: +736.4975)
#     ... and 15 more
#
# P1A_82 - h=10 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 469.038884
#   Non-zero coefficients: 10 / 59
#   Top 10 features selected:
#      1. P1EA_Slope                                          (coef: -3121.6021)
#      2. Atlantic Region Industrial Production Growth        (coef: +1862.6453)
#      3. P1EA_Basis                                          (coef: -1603.4760)
#      4. Capesize Fleet Growth                               (coef: +1075.7749)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +914.5679)
#      6. FFAPmxOI                                            (coef: +891.4501)
#      7. C10                                                 (coef: +811.7309)
#      8. LPDSRA                                              (coef: +797.2907)
#      9. BDRVI                                               (coef: -465.5587)
#     10. Germany BFI Production                              (coef: -144.6051)
#
# P1A_82 - h=10 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 70.548023
#   Top 10 features selected:
#      1. P1EA_Slope                                          (coef: -1833.7487)
#      2. Panamax Orderbook % Fleet                           (coef: +1540.4528)
#      3. P1EA_Basis                                          (coef: -1491.6559)
#      4. P1EA_Contango                                       (coef: -957.8436)
#      5. LPDSRA                                              (coef: +916.4431)
#      6. Industrial Production  OECD                         (coef: +831.8014)
#      7. LIDSRA                                              (coef: +810.4601)
#      8. Atlantic Region Industrial Production Growth        (coef: +784.3870)
#      9. Capesize 100-215,000 dwt Atlantic Deployment        (coef: +779.7789)
#     10. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +774.3898)
#
# P1A_82 - h=10 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 469.038884
#   Non-zero coefficients: 10 / 59
#   Top 15 features selected:
#      1. P1EA_Slope                                          (coef: -3121.6021)
#      2. Atlantic Region Industrial Production Growth        (coef: +1862.6453)
#      3. P1EA_Basis                                          (coef: -1603.4760)
#      4. Capesize Fleet Growth                               (coef: +1075.7749)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +914.5679)
#      6. FFAPmxOI                                            (coef: +891.4501)
#      7. C10                                                 (coef: +811.7309)
#      8. LPDSRA                                              (coef: +797.2907)
#      9. BDRVI                                               (coef: -465.5587)
#     10. Germany BFI Production                              (coef: -144.6051)
#     ... and 5 more
#
# P1A_82 - h=10 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 70.548023
#   Top 15 features selected:
#      1. P1EA_Slope                                          (coef: -1833.7487)
#      2. Panamax Orderbook % Fleet                           (coef: +1540.4528)
#      3. P1EA_Basis                                          (coef: -1491.6559)
#      4. P1EA_Contango                                       (coef: -957.8436)
#      5. LPDSRA                                              (coef: +916.4431)
#      6. Industrial Production  OECD                         (coef: +831.8014)
#      7. LIDSRA                                              (coef: +810.4601)
#      8. Atlantic Region Industrial Production Growth        (coef: +784.3870)
#      9. Capesize 100-215,000 dwt Atlantic Deployment        (coef: +779.7789)
#     10. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +774.3898)
#     ... and 5 more
#
# P1A_82 - h=10 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 469.038884
#   Non-zero coefficients: 10 / 59
#   Top 20 features selected:
#      1. P1EA_Slope                                          (coef: -3121.6021)
#      2. Atlantic Region Industrial Production Growth        (coef: +1862.6453)
#      3. P1EA_Basis                                          (coef: -1603.4760)
#      4. Capesize Fleet Growth                               (coef: +1075.7749)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +914.5679)
#      6. FFAPmxOI                                            (coef: +891.4501)
#      7. C10                                                 (coef: +811.7309)
#      8. LPDSRA                                              (coef: +797.2907)
#      9. BDRVI                                               (coef: -465.5587)
#     10. Germany BFI Production                              (coef: -144.6051)
#     ... and 10 more
#
# P1A_82 - h=10 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 70.548023
#   Top 20 features selected:
#      1. P1EA_Slope                                          (coef: -1833.7487)
#      2. Panamax Orderbook % Fleet                           (coef: +1540.4528)
#      3. P1EA_Basis                                          (coef: -1491.6559)
#      4. P1EA_Contango                                       (coef: -957.8436)
#      5. LPDSRA                                              (coef: +916.4431)
#      6. Industrial Production  OECD                         (coef: +831.8014)
#      7. LIDSRA                                              (coef: +810.4601)
#      8. Atlantic Region Industrial Production Growth        (coef: +784.3870)
#      9. Capesize 100-215,000 dwt Atlantic Deployment        (coef: +779.7789)
#     10. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +774.3898)
#     ... and 10 more
#
# P1A_82 - h=10 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 469.038884
#   Non-zero coefficients: 10 / 59
#   Top 25 features selected:
#      1. P1EA_Slope                                          (coef: -3121.6021)
#      2. Atlantic Region Industrial Production Growth        (coef: +1862.6453)
#      3. P1EA_Basis                                          (coef: -1603.4760)
#      4. Capesize Fleet Growth                               (coef: +1075.7749)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +914.5679)
#      6. FFAPmxOI                                            (coef: +891.4501)
#      7. C10                                                 (coef: +811.7309)
#      8. LPDSRA                                              (coef: +797.2907)
#      9. BDRVI                                               (coef: -465.5587)
#     10. Germany BFI Production                              (coef: -144.6051)
#     ... and 15 more
#
# P1A_82 - h=10 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 70.548023
#   Top 25 features selected:
#      1. P1EA_Slope                                          (coef: -1833.7487)
#      2. Panamax Orderbook % Fleet                           (coef: +1540.4528)
#      3. P1EA_Basis                                          (coef: -1491.6559)
#      4. P1EA_Contango                                       (coef: -957.8436)
#      5. LPDSRA                                              (coef: +916.4431)
#      6. Industrial Production  OECD                         (coef: +831.8014)
#      7. LIDSRA                                              (coef: +810.4601)
#      8. Atlantic Region Industrial Production Growth        (coef: +784.3870)
#      9. Capesize 100-215,000 dwt Atlantic Deployment        (coef: +779.7789)
#     10. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (At  (coef: +774.3898)
#     ... and 15 more
#
# P1A_82 - h=20 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 876.912400
#   Non-zero coefficients: 10 / 59
#   Top 10 features selected:
#      1. FFAPmxOI                                            (coef: +2095.3009)
#      2. Industrial Production  OECD                         (coef: +1900.6275)
#      3. P1EA_Slope                                          (coef: -1631.8581)
#      4. C10                                                 (coef: +972.1684)
#      5. Capesize Fleet Growth                               (coef: +883.4064)
#      6. LPDSRA                                              (coef: +663.2786)
#      7. Atlantic Region Industrial Production Growth        (coef: +455.8004)
#      8. P1EA_Basis                                          (coef: -253.1510)
#      9. 1 Year Timecharter Rate 180,000 dwt eco Bulkcarrie  (coef: +7.5162)
#     10. BDRVI                                               (coef: -2.8243)
#
# P1A_82 - h=20 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 10 features selected:
#      1. FFAPmxOI                                            (coef: +609.9451)
#      2. Industrial Production  OECD                         (coef: +575.0381)
#      3. Atlantic Region Industrial Production Growth        (coef: +572.4511)
#      4. Industrial Production  USA                          (coef: +553.9025)
#      5. P1EA_Slope                                          (coef: -538.2195)
#      6. P1EA_Basis                                          (coef: -518.7891)
#      7. LPDSRA                                              (coef: +439.0416)
#      8. P1EA_Contango                                       (coef: -421.1934)
#      9. C10                                                 (coef: +403.5165)
#     10. Capesize Fleet Growth                               (coef: +397.1813)
#
# P1A_82 - h=20 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 876.912400
#   Non-zero coefficients: 10 / 59
#   Top 15 features selected:
#      1. FFAPmxOI                                            (coef: +2095.3009)
#      2. Industrial Production  OECD                         (coef: +1900.6275)
#      3. P1EA_Slope                                          (coef: -1631.8581)
#      4. C10                                                 (coef: +972.1684)
#      5. Capesize Fleet Growth                               (coef: +883.4064)
#      6. LPDSRA                                              (coef: +663.2786)
#      7. Atlantic Region Industrial Production Growth        (coef: +455.8004)
#      8. P1EA_Basis                                          (coef: -253.1510)
#      9. 1 Year Timecharter Rate 180,000 dwt eco Bulkcarrie  (coef: +7.5162)
#     10. BDRVI                                               (coef: -2.8243)
#     ... and 5 more
#
# P1A_82 - h=20 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 15 features selected:
#      1. FFAPmxOI                                            (coef: +609.9451)
#      2. Industrial Production  OECD                         (coef: +575.0381)
#      3. Atlantic Region Industrial Production Growth        (coef: +572.4511)
#      4. Industrial Production  USA                          (coef: +553.9025)
#      5. P1EA_Slope                                          (coef: -538.2195)
#      6. P1EA_Basis                                          (coef: -518.7891)
#      7. LPDSRA                                              (coef: +439.0416)
#      8. P1EA_Contango                                       (coef: -421.1934)
#      9. C10                                                 (coef: +403.5165)
#     10. Capesize Fleet Growth                               (coef: +397.1813)
#     ... and 5 more
#
# P1A_82 - h=20 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 876.912400
#   Non-zero coefficients: 10 / 59
#   Top 20 features selected:
#      1. FFAPmxOI                                            (coef: +2095.3009)
#      2. Industrial Production  OECD                         (coef: +1900.6275)
#      3. P1EA_Slope                                          (coef: -1631.8581)
#      4. C10                                                 (coef: +972.1684)
#      5. Capesize Fleet Growth                               (coef: +883.4064)
#      6. LPDSRA                                              (coef: +663.2786)
#      7. Atlantic Region Industrial Production Growth        (coef: +455.8004)
#      8. P1EA_Basis                                          (coef: -253.1510)
#      9. 1 Year Timecharter Rate 180,000 dwt eco Bulkcarrie  (coef: +7.5162)
#     10. BDRVI                                               (coef: -2.8243)
#     ... and 10 more
#
# P1A_82 - h=20 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 20 features selected:
#      1. FFAPmxOI                                            (coef: +609.9451)
#      2. Industrial Production  OECD                         (coef: +575.0381)
#      3. Atlantic Region Industrial Production Growth        (coef: +572.4511)
#      4. Industrial Production  USA                          (coef: +553.9025)
#      5. P1EA_Slope                                          (coef: -538.2195)
#      6. P1EA_Basis                                          (coef: -518.7891)
#      7. LPDSRA                                              (coef: +439.0416)
#      8. P1EA_Contango                                       (coef: -421.1934)
#      9. C10                                                 (coef: +403.5165)
#     10. Capesize Fleet Growth                               (coef: +397.1813)
#     ... and 10 more
#
# P1A_82 - h=20 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 876.912400
#   Non-zero coefficients: 10 / 59
#   Top 25 features selected:
#      1. FFAPmxOI                                            (coef: +2095.3009)
#      2. Industrial Production  OECD                         (coef: +1900.6275)
#      3. P1EA_Slope                                          (coef: -1631.8581)
#      4. C10                                                 (coef: +972.1684)
#      5. Capesize Fleet Growth                               (coef: +883.4064)
#      6. LPDSRA                                              (coef: +663.2786)
#      7. Atlantic Region Industrial Production Growth        (coef: +455.8004)
#      8. P1EA_Basis                                          (coef: -253.1510)
#      9. 1 Year Timecharter Rate 180,000 dwt eco Bulkcarrie  (coef: +7.5162)
#     10. BDRVI                                               (coef: -2.8243)
#     ... and 15 more
#
# P1A_82 - h=20 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 25 features selected:
#      1. FFAPmxOI                                            (coef: +609.9451)
#      2. Industrial Production  OECD                         (coef: +575.0381)
#      3. Atlantic Region Industrial Production Growth        (coef: +572.4511)
#      4. Industrial Production  USA                          (coef: +553.9025)
#      5. P1EA_Slope                                          (coef: -538.2195)
#      6. P1EA_Basis                                          (coef: -518.7891)
#      7. LPDSRA                                              (coef: +439.0416)
#      8. P1EA_Contango                                       (coef: -421.1934)
#      9. C10                                                 (coef: +403.5165)
#     10. Capesize Fleet Growth                               (coef: +397.1813)
#     ... and 15 more
#
# --- P3A_82 ---
#
# P3A_82 - h=1 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 72.178354
#   Non-zero coefficients: 22 / 61
#   Top 10 features selected:
#      1. P3EA_Basis                                          (coef: -2272.2945)
#      2. P3EA_Slope                                          (coef: -1275.5194)
#      3. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +1129.2777)
#      4. PDITC                                               (coef: +1091.3982)
#      5. P8-TCE                                              (coef: +953.5948)
#      6. C8                                                  (coef: +901.6675)
#      7. DOPEX                                               (coef: -683.6188)
#      8. India DRI Production                                (coef: -489.8074)
#      9. FFAPmxOI                                            (coef: +488.8199)
#     10. P3EA_Contango                                       (coef: -468.3459)
#
# P3A_82 - h=1 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 81.113083
#   Top 10 features selected:
#      1. P3EA_Basis                                          (coef: -1967.8258)
#      2. P8-TCE                                              (coef: +812.4370)
#      3. P3EA_Slope                                          (coef: -766.1960)
#      4. P3EA_Contango                                       (coef: -668.6363)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +655.6575)
#      6. PDITC                                               (coef: +626.3677)
#      7. C8                                                  (coef: +487.0675)
#      8. PDIC                                                (coef: -375.3763)
#      9. BCI                                                 (coef: +353.3032)
#     10. C5TC                                                (coef: +353.2989)
#
# P3A_82 - h=1 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 72.178354
#   Non-zero coefficients: 22 / 61
#   Top 15 features selected:
#      1. P3EA_Basis                                          (coef: -2272.2945)
#      2. P3EA_Slope                                          (coef: -1275.5194)
#      3. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +1129.2777)
#      4. PDITC                                               (coef: +1091.3982)
#      5. P8-TCE                                              (coef: +953.5948)
#      6. C8                                                  (coef: +901.6675)
#      7. DOPEX                                               (coef: -683.6188)
#      8. India DRI Production                                (coef: -489.8074)
#      9. FFAPmxOI                                            (coef: +488.8199)
#     10. P3EA_Contango                                       (coef: -468.3459)
#     ... and 5 more
#
# P3A_82 - h=1 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 81.113083
#   Top 15 features selected:
#      1. P3EA_Basis                                          (coef: -1967.8258)
#      2. P8-TCE                                              (coef: +812.4370)
#      3. P3EA_Slope                                          (coef: -766.1960)
#      4. P3EA_Contango                                       (coef: -668.6363)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +655.6575)
#      6. PDITC                                               (coef: +626.3677)
#      7. C8                                                  (coef: +487.0675)
#      8. PDIC                                                (coef: -375.3763)
#      9. BCI                                                 (coef: +353.3032)
#     10. C5TC                                                (coef: +353.2989)
#     ... and 5 more
#
# P3A_82 - h=1 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 72.178354
#   Non-zero coefficients: 22 / 61
#   Top 20 features selected:
#      1. P3EA_Basis                                          (coef: -2272.2945)
#      2. P3EA_Slope                                          (coef: -1275.5194)
#      3. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +1129.2777)
#      4. PDITC                                               (coef: +1091.3982)
#      5. P8-TCE                                              (coef: +953.5948)
#      6. C8                                                  (coef: +901.6675)
#      7. DOPEX                                               (coef: -683.6188)
#      8. India DRI Production                                (coef: -489.8074)
#      9. FFAPmxOI                                            (coef: +488.8199)
#     10. P3EA_Contango                                       (coef: -468.3459)
#     ... and 10 more
#
# P3A_82 - h=1 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 81.113083
#   Top 20 features selected:
#      1. P3EA_Basis                                          (coef: -1967.8258)
#      2. P8-TCE                                              (coef: +812.4370)
#      3. P3EA_Slope                                          (coef: -766.1960)
#      4. P3EA_Contango                                       (coef: -668.6363)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +655.6575)
#      6. PDITC                                               (coef: +626.3677)
#      7. C8                                                  (coef: +487.0675)
#      8. PDIC                                                (coef: -375.3763)
#      9. BCI                                                 (coef: +353.3032)
#     10. C5TC                                                (coef: +353.2989)
#     ... and 10 more
#
# P3A_82 - h=1 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 72.178354
#   Non-zero coefficients: 22 / 61
#   Top 25 features selected:
#      1. P3EA_Basis                                          (coef: -2272.2945)
#      2. P3EA_Slope                                          (coef: -1275.5194)
#      3. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +1129.2777)
#      4. PDITC                                               (coef: +1091.3982)
#      5. P8-TCE                                              (coef: +953.5948)
#      6. C8                                                  (coef: +901.6675)
#      7. DOPEX                                               (coef: -683.6188)
#      8. India DRI Production                                (coef: -489.8074)
#      9. FFAPmxOI                                            (coef: +488.8199)
#     10. P3EA_Contango                                       (coef: -468.3459)
#     ... and 15 more
#
# P3A_82 - h=1 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 81.113083
#   Top 25 features selected:
#      1. P3EA_Basis                                          (coef: -1967.8258)
#      2. P8-TCE                                              (coef: +812.4370)
#      3. P3EA_Slope                                          (coef: -766.1960)
#      4. P3EA_Contango                                       (coef: -668.6363)
#      5. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +655.6575)
#      6. PDITC                                               (coef: +626.3677)
#      7. C8                                                  (coef: +487.0675)
#      8. PDIC                                                (coef: -375.3763)
#      9. BCI                                                 (coef: +353.3032)
#     10. C5TC                                                (coef: +353.2989)
#     ... and 15 more
#
# P3A_82 - h=5 - Lasso Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 173.812853
#   Non-zero coefficients: 19 / 61
#   Top 10 features selected:
#      1. P3EA_Basis                                          (coef: -2394.7263)
#      2. PDITC                                               (coef: +1711.7406)
#      3. P3EA_Slope                                          (coef: -1489.6224)
#      4. PDIC                                                (coef: -935.4173)
#      5. Capesize Fleet Growth                               (coef: +746.9937)
#      6. India DRI Production                                (coef: -739.7475)
#      7. 1 Year Timecharter Rate 180,000 dwt Scrubber-Fitte  (coef: +583.7576)
#      8. Port Congestion Index - Panamax Bulkcarriers In Po  (coef: +418.5396)
#      9. C5TC                                                (coef: +328.7910)
#     10. Japan Seaborne Iron Ore Imports                     (coef: +315.1448)
#
# P3A_82 - h=5 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 53.366992
#   Top 10 features selected:
#      1. P3EA_Basis                                          (coef: -2222.5349)
#      2. P3EA_Slope                                          (coef: -719.1797)
#      3. PDIC                                                (coef: -684.9576)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +650.1924)
#      5. PDITC                                               (coef: +636.6559)
#      6. P3EA_Contango                                       (coef: -602.5872)
#      7. P8-TCE                                              (coef: +548.3784)
#      8. C5TC                                                (coef: +373.4284)
#      9. BCI                                                 (coef: +373.1904)
#     10. India DRI Production                                (coef: -361.7977)
#
# P3A_82 - h=5 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 173.812853
#   Non-zero coefficients: 19 / 61
#   Top 15 features selected:
#      1. P3EA_Basis                                          (coef: -2394.7263)
#      2. PDITC                                               (coef: +1711.7406)
#      3. P3EA_Slope                                          (coef: -1489.6224)
#      4. PDIC                                                (coef: -935.4173)
#      5. Capesize Fleet Growth                               (coef: +746.9937)
#      6. India DRI Production                                (coef: -739.7475)
#      7. 1 Year Timecharter Rate 180,000 dwt Scrubber-Fitte  (coef: +583.7576)
#      8. Port Congestion Index - Panamax Bulkcarriers In Po  (coef: +418.5396)
#      9. C5TC                                                (coef: +328.7910)
#     10. Japan Seaborne Iron Ore Imports                     (coef: +315.1448)
#     ... and 5 more
#
# P3A_82 - h=5 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 53.366992
#   Top 15 features selected:
#      1. P3EA_Basis                                          (coef: -2222.5349)
#      2. P3EA_Slope                                          (coef: -719.1797)
#      3. PDIC                                                (coef: -684.9576)
#      4. 5 Year Timecharter Rate 75,000 dwt Bulkcarrier (Pa  (coef: +650.1924)
#      5. PDITC                                               (coef: +636.6559)
#      6. P3EA_Contango                                       (coef: -602.5872)
#      7. P8-TCE                                              (coef: +548.3784)
#      8. C5TC                                                (coef: +373.4284)
#      9. BCI                                                 (coef: +373.1904)
# ...
#      9. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -627.0760)
#     10. LPDSRA                                              (coef: +327.8595)
#
# P3A_82 - h=20 - Ridge Feature Selection (top 10)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 10 features selected:
#      1. P3EA_Basis                                          (coef: -577.7008)
#      2. P3EA_Curvature                                      (coef: -527.1561)
#      3. FFAPmxOI                                            (coef: +402.3809)
#      4. Capesize Fleet Growth                               (coef: +388.6578)
#      5. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -362.5906)
#      6. P3EA_Slope                                          (coef: -355.0176)
#      7. LPDSRA                                              (coef: +354.8477)
#      8. P3EA_Contango                                       (coef: -353.3651)
#      9. Japan Seaborne Iron Ore Imports                     (coef: +345.6773)
#     10. BDRVI                                               (coef: -327.5471)
#
# P3A_82 - h=20 - Lasso Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 530.933534
#   Non-zero coefficients: 12 / 61
#   Top 15 features selected:
#      1. BDRVI                                               (coef: -1756.5416)
#      2. P3EA_Contango                                       (coef: -1444.0899)
#      3. FFAPmxOI                                            (coef: +1242.4076)
#      4. Capesize Fleet Growth                               (coef: +988.8956)
#      5. Panamax Bulkcarrier Fleet - Average Age             (coef: -947.1104)
#      6. P3EA_Basis                                          (coef: -917.5183)
#      7. P3EA_Curvature                                      (coef: -675.4903)
#      8. Japan Seaborne Iron Ore Imports                     (coef: +642.1786)
#      9. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -627.0760)
#     10. LPDSRA                                              (coef: +327.8595)
#     ... and 5 more
#
# P3A_82 - h=20 - Ridge Feature Selection (top 15)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 15 features selected:
#      1. P3EA_Basis                                          (coef: -577.7008)
#      2. P3EA_Curvature                                      (coef: -527.1561)
#      3. FFAPmxOI                                            (coef: +402.3809)
#      4. Capesize Fleet Growth                               (coef: +388.6578)
#      5. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -362.5906)
#      6. P3EA_Slope                                          (coef: -355.0176)
#      7. LPDSRA                                              (coef: +354.8477)
#      8. P3EA_Contango                                       (coef: -353.3651)
#      9. Japan Seaborne Iron Ore Imports                     (coef: +345.6773)
#     10. BDRVI                                               (coef: -327.5471)
#     ... and 5 more
#
# P3A_82 - h=20 - Lasso Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 530.933534
#   Non-zero coefficients: 12 / 61
#   Top 20 features selected:
#      1. BDRVI                                               (coef: -1756.5416)
#      2. P3EA_Contango                                       (coef: -1444.0899)
#      3. FFAPmxOI                                            (coef: +1242.4076)
#      4. Capesize Fleet Growth                               (coef: +988.8956)
#      5. Panamax Bulkcarrier Fleet - Average Age             (coef: -947.1104)
#      6. P3EA_Basis                                          (coef: -917.5183)
#      7. P3EA_Curvature                                      (coef: -675.4903)
#      8. Japan Seaborne Iron Ore Imports                     (coef: +642.1786)
#      9. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -627.0760)
#     10. LPDSRA                                              (coef: +327.8595)
#     ... and 10 more
#
# P3A_82 - h=20 - Ridge Feature Selection (top 20)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 20 features selected:
#      1. P3EA_Basis                                          (coef: -577.7008)
#      2. P3EA_Curvature                                      (coef: -527.1561)
#      3. FFAPmxOI                                            (coef: +402.3809)
#      4. Capesize Fleet Growth                               (coef: +388.6578)
#      5. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -362.5906)
#      6. P3EA_Slope                                          (coef: -355.0176)
#      7. LPDSRA                                              (coef: +354.8477)
#      8. P3EA_Contango                                       (coef: -353.3651)
#      9. Japan Seaborne Iron Ore Imports                     (coef: +345.6773)
#     10. BDRVI                                               (coef: -327.5471)
#     ... and 10 more
#
# P3A_82 - h=20 - Lasso Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running LassoCV (finding optimal alpha)...
#   Optimal alpha: 530.933534
#   Non-zero coefficients: 12 / 61
#   Top 25 features selected:
#      1. BDRVI                                               (coef: -1756.5416)
#      2. P3EA_Contango                                       (coef: -1444.0899)
#      3. FFAPmxOI                                            (coef: +1242.4076)
#      4. Capesize Fleet Growth                               (coef: +988.8956)
#      5. Panamax Bulkcarrier Fleet - Average Age             (coef: -947.1104)
#      6. P3EA_Basis                                          (coef: -917.5183)
#      7. P3EA_Curvature                                      (coef: -675.4903)
#      8. Japan Seaborne Iron Ore Imports                     (coef: +642.1786)
#      9. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -627.0760)
#     10. LPDSRA                                              (coef: +327.8595)
#     ... and 15 more
#
# P3A_82 - h=20 - Ridge Feature Selection (top 25)
# ------------------------------------------------------------
#   Handling missing values in features...
#   Running RidgeCV (finding optimal alpha)...
#   Optimal alpha: 1000.000000
#   Top 25 features selected:
#      1. P3EA_Basis                                          (coef: -577.7008)
#      2. P3EA_Curvature                                      (coef: -527.1561)
#      3. FFAPmxOI                                            (coef: +402.3809)
#      4. Capesize Fleet Growth                               (coef: +388.6578)
#      5. Pacific Region Port Calls - Deep Sea Cargo Vessels  (coef: -362.5906)
#      6. P3EA_Slope                                          (coef: -355.0176)
#      7. LPDSRA                                              (coef: +354.8477)
#      8. P3EA_Contango                                       (coef: -353.3651)
#      9. Japan Seaborne Iron Ore Imports                     (coef: +345.6773)
#     10. BDRVI                                               (coef: -327.5471)
#     ... and 15 more
#
# ================================================================================
# Feature selection complete! Testing XGBoost with selected features...
# ================================================================================
#
# ================================================================================
# PHASE 2: XGBOOST TRAINING ON SELECTED FEATURES
# ================================================================================
#
# --- P1A_82 ---
#
# Horizon 1:
#   Training XGBoost with LASSO 10 features... RMSE=$4,066.76, R²=-2.4139
#   Training XGBoost with RIDGE 10 features... RMSE=$5,075.01, R²=-4.3165
#   Training XGBoost with LASSO 15 features... RMSE=$5,014.99, R²=-4.1915
#   Training XGBoost with RIDGE 15 features... RMSE=$4,843.08, R²=-3.8417
#   Training XGBoost with LASSO 20 features... RMSE=$6,017.00, R²=-6.4733
#   Training XGBoost with RIDGE 20 features... RMSE=$5,658.66, R²=-5.6097
#   Training XGBoost with LASSO 25 features... RMSE=$6,093.33, R²=-6.6641
#   Training XGBoost with RIDGE 25 features... RMSE=$5,297.21, R²=-4.7923
#
# Horizon 5:
#   Training XGBoost with LASSO 10 features... RMSE=$3,958.83, R²=-2.6018
#   Training XGBoost with RIDGE 10 features... RMSE=$3,845.83, R²=-2.3991
#   Training XGBoost with LASSO 15 features... RMSE=$2,715.21, R²=-0.6943
#   Training XGBoost with RIDGE 15 features... RMSE=$3,496.69, R²=-1.8100
#   Training XGBoost with LASSO 20 features... RMSE=$2,227.64, R²=-0.1405
#   Training XGBoost with RIDGE 20 features... RMSE=$3,169.07, R²=-1.3081
#   Training XGBoost with LASSO 25 features... RMSE=$2,295.08, R²=-0.2106
#   Training XGBoost with RIDGE 25 features... RMSE=$3,774.52, R²=-2.2742
#
# Horizon 10:
#   Training XGBoost with LASSO 10 features... RMSE=$4,754.98, R²=-4.0420
#   Training XGBoost with RIDGE 10 features... RMSE=$5,232.17, R²=-5.1048
#   Training XGBoost with LASSO 15 features... RMSE=$4,344.89, R²=-3.2099
#   Training XGBoost with RIDGE 15 features... RMSE=$3,806.61, R²=-2.2314
#   Training XGBoost with LASSO 20 features... RMSE=$5,377.86, R²=-5.4495
#   Training XGBoost with RIDGE 20 features... RMSE=$3,545.81, R²=-1.8037
#   Training XGBoost with LASSO 25 features... RMSE=$4,710.21, R²=-3.9475
#   Training XGBoost with RIDGE 25 features... RMSE=$3,790.64, R²=-2.2043
#
# Horizon 20:
#   Training XGBoost with LASSO 10 features... RMSE=$9,376.74, R²=-17.4866
#   Training XGBoost with RIDGE 10 features... RMSE=$8,350.35, R²=-13.6610
#   Training XGBoost with LASSO 15 features... RMSE=$7,999.57, R²=-12.4551
#   Training XGBoost with RIDGE 15 features... RMSE=$8,984.47, R²=-15.9722
#   Training XGBoost with LASSO 20 features... RMSE=$6,774.46, R²=-8.6495
#   Training XGBoost with RIDGE 20 features... RMSE=$10,739.79, R²=-23.2519
#   Training XGBoost with LASSO 25 features... RMSE=$6,897.39, R²=-9.0028
#   Training XGBoost with RIDGE 25 features... RMSE=$8,830.64, R²=-15.3960
#
# --- P3A_82 ---
#
# Horizon 1:
#   Training XGBoost with LASSO 10 features... RMSE=$1,793.49, R²=0.5020
#   Training XGBoost with RIDGE 10 features... RMSE=$1,583.44, R²=0.6118
#   Training XGBoost with LASSO 15 features... RMSE=$1,738.77, R²=0.5319
#   Training XGBoost with RIDGE 15 features... RMSE=$1,582.61, R²=0.6122
#   Training XGBoost with LASSO 20 features... RMSE=$1,268.59, R²=0.7508
#   Training XGBoost with RIDGE 20 features... RMSE=$2,131.39, R²=0.2966
#   Training XGBoost with LASSO 25 features... RMSE=$1,507.54, R²=0.6481
#   Training XGBoost with RIDGE 25 features... RMSE=$2,183.82, R²=0.2616
#
# Horizon 5:
#   Training XGBoost with LASSO 10 features... RMSE=$4,601.74, R²=-2.2432
#   Training XGBoost with RIDGE 10 features... RMSE=$1,516.63, R²=0.6477
#   Training XGBoost with LASSO 15 features... RMSE=$2,231.92, R²=0.2371
#   Training XGBoost with RIDGE 15 features... RMSE=$1,594.82, R²=0.6105
#   Training XGBoost with LASSO 20 features... RMSE=$1,507.35, R²=0.6520
#   Training XGBoost with RIDGE 20 features... RMSE=$1,615.60, R²=0.6002
#   Training XGBoost with LASSO 25 features... RMSE=$1,204.40, R²=0.7778
#   Training XGBoost with RIDGE 25 features... RMSE=$1,792.84, R²=0.5077
#
# Horizon 10:
#   Training XGBoost with LASSO 10 features... RMSE=$2,011.34, R²=0.3280
#   Training XGBoost with RIDGE 10 features... RMSE=$1,793.62, R²=0.4656
#   Training XGBoost with LASSO 15 features... RMSE=$1,905.74, R²=0.3967
#   Training XGBoost with RIDGE 15 features... RMSE=$1,813.47, R²=0.4537
#   Training XGBoost with LASSO 20 features... RMSE=$1,629.78, R²=0.5588
#   Training XGBoost with RIDGE 20 features... RMSE=$1,871.17, R²=0.4184
#   Training XGBoost with LASSO 25 features... RMSE=$1,629.36, R²=0.5590
#   Training XGBoost with RIDGE 25 features... RMSE=$1,817.36, R²=0.4513
#
# Horizon 20:
#   Training XGBoost with LASSO 10 features... RMSE=$3,382.60, R²=-1.3866
#   Training XGBoost with RIDGE 10 features... RMSE=$3,707.27, R²=-1.8667
#   Training XGBoost with LASSO 15 features... RMSE=$4,012.32, R²=-2.3579
#   Training XGBoost with RIDGE 15 features... RMSE=$3,368.55, R²=-1.3668
#   Training XGBoost with LASSO 20 features... RMSE=$3,614.81, R²=-1.7255
#   Training XGBoost with RIDGE 20 features... RMSE=$3,177.12, R²=-1.1054
#   Training XGBoost with LASSO 25 features... RMSE=$4,036.70, R²=-2.3988
#   Training XGBoost with RIDGE 25 features... RMSE=$3,395.93, R²=-1.4054
#
# ================================================================================
# XGBoost training complete!
# ================================================================================
#
# ================================================================================
# RESULTS SUMMARY: FEATURE SELECTION IMPACT
# ================================================================================
#
# P1A_82:
# --------------------------------------------------------------------------------
# Top 5 configurations (by RMSE):
#   1. LASSO 10 features: RMSE=$4,066.76  |  R²=-2.4139
#   2. RIDGE 15 features: RMSE=$4,843.08  |  R²=-3.8417
#   3. LASSO 15 features: RMSE=$5,014.99  |  R²=-4.1915
#   4. RIDGE 10 features: RMSE=$5,075.01  |  R²=-4.3165
#   5. RIDGE 25 features: RMSE=$5,297.21  |  R²=-4.7923
#
# ✓ BEST: LASSO with 10 features
#   RMSE: $4,066.76
#   R²:   -2.4139
#
# P3A_82:
# --------------------------------------------------------------------------------
# Top 5 configurations (by RMSE):
#   1. LASSO 20 features: RMSE=$1,268.59  |  R²= 0.7508
#   2. LASSO 25 features: RMSE=$1,507.54  |  R²= 0.6481
#   3. RIDGE 15 features: RMSE=$1,582.61  |  R²= 0.6122
#   4. RIDGE 10 features: RMSE=$1,583.44  |  R²= 0.6118
#   5. LASSO 15 features: RMSE=$1,738.77  |  R²= 0.5319
#
# ✓ BEST: LASSO with 20 features
#   RMSE: $1,268.59
#   R²:   0.7508
#
# ================================================================================
# BASELINE COMPARISON (h=1)
# ================================================================================
#
# P1A_82:
#   XGBoost LASSO             (10 feat): RMSE $  4,066.76  |  R² -2.4139
#   XGBoost FULL              (59 feat): RMSE $  4,284.31  |  R² -2.7900
#   SARIMAX                   (12 feat): RMSE $  7,573.66  |  R²     N/A
#   XGBoost CORE              (12 feat): RMSE $       nan  |  R²     N/A
#
# P3A_82:
#   XGBoost FULL              (61 feat): RMSE $  1,098.56  |  R²  0.8100
#   XGBoost LASSO             (20 feat): RMSE $  1,268.59  |  R²  0.7508
#   SARIMAX                   (12 feat): RMSE $  2,477.18  |  R²     N/A
#   XGBoost CORE              (12 feat): RMSE $       nan  |  R²     N/A
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
# [SAVED] xgboost_feature_selection_results.csv
# [SAVED] Feature importance CSVs (16 files)
# [SAVED] baseline_comparison_all_methods.csv
# [SAVED] metadata.json
#
# ================================================================================
# SCRIPT COMPLETE!
# ================================================================================
#
# Outputs saved to: data/models/feature_selection/
#
# Key files:
#   - xgboost_feature_selection_results.csv: All configurations tested
#   - baseline_comparison_all_methods.csv: Comparison with SARIMAX and full XGBoost
#   - plots/: Feature importance visualizations
#
# Next steps:
#   1. Review baseline_comparison_all_methods.csv
#   2. Check if P1A R² improved (should be positive)
#   3. Identify optimal feature count (sweet spot between 10-25)
#   4. Use best configuration for final production model
# ================================================================================
